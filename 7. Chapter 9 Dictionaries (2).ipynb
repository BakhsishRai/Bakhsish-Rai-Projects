# %% [markdown]
# # Dictionary Lesson
#
# 1. Creating a Dictionary
# 2. Finding Keys and Values in a Dictionary
# 3. Updating a Dictionary
# 4. Removing Keys from a Dictionary
# 5. Checking a Dictionary
# 6. Looping a Dictionary
# 7. Other Dictionary Methods
# 8. Dictionary Operations
# 9. Logical Thinking Practice
#
# # Class Activites

# %% [markdown]
# # IMPORTANT
#
# ## Dictionary vs Lists
#
# **Dictionaries**
# * Unordered
# * Accessed via keys
# * Collection of key value pairs
# * Preferred when you have unique key values
# * No duplicate keys
#
# **Lists**
# * Ordered
# * Accessed via index
# * Collection of elements
# * Preferred for ordered data
# * Allows for duplicate values

# %% [markdown]
# # About Dictionaries
#
# In a dictionary, the **key** is a unique identifier where we can find the data and the **value** is the data
#
# A dictionary key must be of a type that is **immutable**.
#
# For example, you can use an **integer, float, string, or Boolean as a dictionary key.**
#
# However, neither a list nor another dictionary can serve as a dictionary key, because **lists and dictionaries are mutable.**
#
# Also, a dictionary key must be unique. For example, you can't have two dictionary keys that say "name".
#
# The order of items in a dictionary is preserved. That means when you iterate through a dictionary, the items come out in the order they were created in the dictionary.
#
# **the label = key**
#
# **the item = value**

# %%
# 1.1 Creating a Dictionary
# student dictionary
student = {"name": "Hannah", 
           "age": 22, 
           "level": "Senior", 
           "major": "Computer Science", 
           "courses": ["Intro to Bio", "Python Programming", "Data Algorithms"]}

# check results
print(student)
# Out:
# {'name': 'Hannah', 'age': 22, 'level': 'Senior', 'major': 'Computer Science', 'courses': ['Intro to Bio', 'Python Programming', 'Data Algorithms']}

# %%
# 1.2 Creating a Dictionary from Lists 

# list 1
people = ["Tim", "Amy", "Roger", "Nicole"]

# list 2
lang = ["Python", "R", "Kotlin", "SQL"]

# creating a new list
newdict = dict(zip(people, lang))

# check results
print(newdict)
# Out:
# {'Tim': 'Python', 'Amy': 'R', 'Roger': 'Kotlin', 'Nicole': 'SQL'}

# %%
# 1.3 Creating an empty Dictionary

# using dict function
emptyDict = dict()

# using empty curly brackets
anotherEmptyDict = {}

# check results
print(emptyDict)
print(anotherEmptyDict)
# Out:
# {}
# {}

# %%
# 1.4 Creating a Dictionary with dict function 

texas = dict(capital = "Austin", 
             flower = "Blue Bonnet", 
             bird = "Mockingbird", 
             tree = "Pecan")

# check results
print(texas)
# Out:
# {'capital': 'Austin', 'flower': 'Blue Bonnet', 'bird': 'Mockingbird', 'tree': 'Pecan'}

# %%
# 1.5 Converting a List to a Dictionary

# the list must have two values that correspond to a key and value

# nested list
nestedList = [[1, "a"], [2, "b"], [3, "c"], [4, "d"]]

# converting list to dictionary
newDict = dict(nestedList)

# check results
print(newDict)
# Out:
# {1: 'a', 2: 'b', 3: 'c', 4: 'd'}

# %%
# 2.1 Finding Keys in a Dictionary

# what is the value of name key
print(student["name"])

# what is the value of age key
print(student["age"])

# what is the value of level key
print(student["level"])

# what is the value of courses key
print(student["courses"])
# Out:
# Hannah
# 22
# Senior
# ['Intro to Bio', 'Python Programming', 'Data Algorithms']

# %%
# 2.2 Finding Keys and Values in a Dictionary
# this is what happens when you try to use a key that does not exists

student["phone"]

# This will throw an error because that key does not exist
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 4>()
#       1 # 2.2 Finding Keys and Values in a Dictionary
#       2 # this is what happens when you try to use a key that does not exists
# ----> 4 student["phone"]
#
# KeyError: 'phone'

# %%
# 2.3 Finding Keys and Values in a Dictionary
# use get.method for a cleaner retrieval. It does not throw an error

# print key for phone key
print(student.get("phone")) # if the key does not exist, it returns none

# Put in a default message
print(student.get("phone", "This key does not exist.")) 

# if the key exits, it returns the value
print(student.get("major"))
# Out:
# None
# This key does not exist.
# Computer Science

# %%
# 3.1 Updating a Dictionary - adding a new key to a dictionary
student["phone"] = "123-456-7890"


# check results
print(student)
# Out:
# {'name': 'Hannah', 'age': 22, 'level': 'Senior', 'major': 'Computer Science', 'courses': ['Intro to Bio', 'Python Programming', 'Data Algorithms'], 'phone': '123-456-7890'}

# %%
# 3.2 Updating a Dictionary - if the key already exists, then the value will update

# check phone number
print(student.get("phone"))

# update phone number
student["phone"] = "456-7890"

# check results
print(student.get("phone"))
# Out:
# 123-456-7890
# 456-7890

# %%
# 3.3 Updating a Dictionary - you can also update values using update method

# check dictionary
print(student)

# update values
student.update({"name": "Lisa", "age": 31, "level": "Junior", "major": "Accounting"})

# check results
print(student)
# Out:
# {'name': 'Hannah', 'age': 22, 'level': 'Senior', 'major': 'Computer Science', 'courses': ['Intro to Bio', 'Python Programming', 'Data Algorithms'], 'phone': '456-7890'}
# {'name': 'Lisa', 'age': 31, 'level': 'Junior', 'major': 'Accounting', 'courses': ['Intro to Bio', 'Python Programming', 'Data Algorithms'], 'phone': '456-7890'}

# %%
# 4.1 Removing Keys from a Dictionary - deleting a specific key and its value - Method 1
del(student["age"])

# check results
print(student)
# Out:
# {'name': 'Lisa', 'level': 'Junior', 'major': 'Accounting', 'courses': ['Intro to Bio', 'Python Programming', 'Data Algorithms'], 'phone': '456-7890'}

# %%
# 4.2 Removing Keys from a Dictionary - deleting a specific key and its value - Method 2

# assigning popped key to a variable and popping it
popped = student.pop("courses")

# check results

# popped variable
print(popped)

# checking dictionary
print(student)
# Out:
# ['Intro to Bio', 'Python Programming', 'Data Algorithms']
# {'name': 'Lisa', 'level': 'Junior', 'major': 'Accounting', 'phone': '456-7890'}

# %%
# 5.1 Checking a Dictionary - check the number of keys in dictionary
len(student.keys())
# Out:
# 4

# %%
# 5.2 Checking a Dictionary - check the number of values in dictionary
len(student.values())
# Out:
# 4

# %%
# 5.3 Checking a Dictionary - see all the keys in dictionary
student.keys()
# Out:
# dict_keys(['name', 'level', 'major', 'phone'])

# %%
# 5.4 Checking a Dictionary - see all values in dictionary
student.values()
# Out:
# dict_values(['Lisa', 'Junior', 'Accounting', '456-7890'])

# %%
# 5.5 Checking a Dictionary - see keys and values in dictionary
student.items()
# Out:
# dict_items([('name', 'Lisa'), ('level', 'Junior'), ('major', 'Accounting'), ('phone', '456-7890')])

# %%
# 6.1 Looping a Dictionary 

for key, value in student.items():
    print(key, value)
# Out:
# name Lisa
# level Junior
# major Accounting
# phone 456-7890

# %%
# 6.2 Looping a Dictionary - enumerating

for key, value in enumerate(student.items()):
    print(key, value)
# Out:
# 0 ('name', 'Lisa')
# 1 ('level', 'Junior')
# 2 ('major', 'Accounting')
# 3 ('phone', '456-7890')

# %%
# 6.3 Looping a Dictionary - keys

for key in enumerate(student.keys()):
    print(key)
# Out:
# (0, 'name')
# (1, 'level')
# (2, 'major')
# (3, 'phone')

# %%
# 6.4 Looping a Dictionary - values

for values in enumerate(student.values()):
    print(values)

# Class: What do I have to do to start the list at 1 instead of 0?
# Out:
# (0, 'Lisa')
# (1, 'Junior')
# (2, 'Accounting')
# (3, '456-7890')

# %%
# 7.1 Other Dictionary Methods 

# create a dictionary
example = {1: "one", 2: "two", 3: "three", 4: "four", 5 : "five"}

# check available methods
dir(example)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
# 7.1 Other Dictionary Methods - copy
examplecopy = example.copy()

# check results
print(examplecopy)
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: 'five'}

# %%
# 7.2 Other Dictionary Methods - popitems

# pop last key value pair

# dictionary
print(example)

# pops last key value pair
example.popitem()

# check results
print(example)
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: 'five'}
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
# 7.3 Other Dictionary Methods - pop

# pops a specific item

# dictionary
print(example)

# pops 3
example.pop(3)

# check results
print(example)
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}
# {1: 'one', 2: 'two', 4: 'four'}

# %%
# 7.4 Other Dictionary Methods - clear

# clear items in a dictionary
example.clear()

# check results
print(example)
# Out:
# {}

# %%
# 8 Dictionary Operations -  to check if a key is in a dictionary, use the "in" operator

# creating a dictionary
mainCharacters = dict()

anime = ["naruto", "kenshin", "inuyasha", "yusuke", "inuyasha", "ichigo", "goku"]

# checking to see if kakashi is in dictionary
print("kakashi" in mainCharacters)

# checking to see if yuji "not in" dictionary
print("yuji" not in mainCharacters)
# Out:
# False
# True

# %%
# # 8 Dictionary Operations - to check if a key is in a dictionary, use the "in" operator

mainCharacters = dict()

anime = ["naruto", "kenshin", "inuyasha", "yusuke", "inuyasha", "ichigo", "goku"]

for names in anime: # creating a for loop 
    
    if names not in mainCharacters: # if the names are not in the dictionary
        
        mainCharacters[names] = 1 
        # add the name to the dictionary and assign it a value of 1
        
    else: # otherwise
        mainCharacters[names] = mainCharacters[names] + 1 
        # add one to the value for every key you see
        
print(mainCharacters) # print the dictionary
# Out:
# {'naruto': 1, 'kenshin': 1, 'inuyasha': 2, 'yusuke': 1, 'ichigo': 1, 'goku': 1}

# %% [markdown]
# ## Using get method to add items to a dictionary
#
# **We're going to replicate the code above using get method**

# %%
# Note to Nnenna: take out comment to explain this
#unknownKey = mainCharacters.get("asta", 1)

# mainCharacters = dictionary
# .get() = method
# asta = key
# 1 = default value

# Translation: Look in the mainCharacters dictionary.
# If the key "asta" exists, then retrieve that value
# If it does not exist, then add it to the dictionary
# and give it a default value of 1.

# Now we're going to recreate the loop from before

mainCharacters = dict() # same thing from before

anime = ["naruto", "kenshin", "yusuke", 
         "inuyasha", "ichigo", "goku", "inuyasha"] # same thing from before

for names in anime: # creating a for loop 
    
    if names not in mainCharacters: # if the names are not in the dictionary
        
        #if names is not in the dictionary, set that name to 1
        mainCharacters[names] = 1

        # add asta to the dictionary and assign it a value of 1
        mainCharacters["asta"] = mainCharacters.get("asta", 1) 
        
        
    else: 
        #else go get the old value and add 1 to it and update the value
        mainCharacters[names] = mainCharacters[names] + 1 

    # Translation: Same thing as before, but now we're telling Python 
    # to the default value of 1   
print(mainCharacters) # print the dictionary

# now we added "asta" to the dictionary as well as other characters
# Out:
# {'naruto': 1, 'asta': 1, 'kenshin': 1, 'yusuke': 1, 'inuyasha': 2, 'ichigo': 1, 'goku': 1}

# %%
# now we're adding kakashi to the dictionary

for names in anime:
    
    if names not in mainCharacters:# if the names are not in the dictionary
        
        #if names is not in the dictionary, set that name to 1
        mainCharacters[names] = 1
    
    else:
        # add kakashi to the dictionary and assign it a value of 2
        mainCharacters["kakashi"] = mainCharacters.get("kakashi", 2) 

    
print(mainCharacters)
# Out:
# {'naruto': 1, 'asta': 1, 'kenshin': 1, 'yusuke': 1, 'inuyasha': 2, 'ichigo': 1, 'goku': 1, 'kakashi': 2}

# %% [markdown]
# # 10 Practice Logical Thinking Skills
#
# ## Explain why you don't see "Plan B"

# %%
x = 5

if x >= 5:
    print("Plan A")
else:
    print("Plan B")
# Out:
# Plan A

# %% [markdown]
# ## Explain why you DO NOT see "Plan C"

# %%
numbers = [1, 2, 3, 4]

x = 5

for digit in numbers:
    if x >=5:
        print(digit)
    else:
        print("Plan C")
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Explain why "asta" is NOT in the dictionary.
#
# ## Then explain how to fix it.

# %%
mainCharacters = dict() 

anime = ["naruto", "kenshin", "yusuke", 
         "inuyasha", "ichigo", "goku"] 

for names in anime: 
    
    if names not in mainCharacters:
        
        #if names is not in the dictionary, set that name to 1
        mainCharacters[names] = 1
        

        
    else: 
        #else go get the old value and add 1 to it and update the value
        mainCharacters[names] = mainCharacters[names] + 1 
        
        # add asta to the dictionary and assign it a value of 1
        mainCharacters["asta"] = mainCharacters.get("asta", 1)         

        
print(mainCharacters)
# Out:
# {'naruto': 1, 'kenshin': 1, 'yusuke': 1, 'inuyasha': 1, 'ichigo': 1, 'goku': 1}

# %% [markdown]
# # Class Activity 1 - Declaration of Independence
#
# Create a dictionary that counts the frequency of all the words in the declaration of independence.
#
# Road Map
# 1. Create an empty dictionary
# 2. Import the declaration
# 3. Convert the declaration into a list
# 4. Loop over the list to add it to the empty dictionary

# %%
# Class Activity 1 Solution
# create an empty dictionary
declaration = {}

# import the declaration - using built-in open function with default "r" to read the file
file = open('declarationofind.txt', 'r')

# creating a variable to hold the play
words = file.read() 

# lowercase words
wordsLowercase = words.lower()

# convert string to a list - because you can iterate over lists
wordsList = wordsLowercase.split()

# sorting list
wordsSorted = wordsList.sort()

# creating a for loop to add words to empty dictionary
for words in wordsList:
    
    if words not in declaration: 
        
        declaration[words] = 1        
        
    else: 
        declaration[words] = declaration[words] + 1 

# check results
print(declaration)
# Out:
# {'a': 16, 'abdicated': 1, 'abolish': 1, 'abolishing': 3, 'absolute': 3, 'absolved': 1, 'abuses': 1, 'accommodation': 1, 'accordingly': 1, 'accustomed.': 1, 'acquiesce': 1, 'act': 1, 'acts': 2, 'administration': 1, 'affected': 1, 'after': 1, 'against': 2, 'ages,': 2, 'all': 10, 'allegiance': 1, 'alliances,': 1, 'alone,': 1, 'already': 1, 'alter': 2, 'altering': 1, 'america,': 1, 'among': 5, 'amongst': 1, 'amount': 1, 'an': 5, 'and': 57, 'annihilation,': 1, 'another,': 1, 'answered': 1, 'any': 2, 'appealed': 1, 'appealing': 1, 'appropriations': 1, 'arbitrary': 1, 'are': 8, 'are,': 1, 'armed': 1, 'armies': 1, 'armies,': 1, 'arms': 1, 'as': 4, 'assembled,': 1, 'assent': 4, 'assume': 1, 'at': 4, 'attempts': 1, 'attend': 1, 'attentions': 1, 'authority': 1, 'away': 1, 'bands': 1, 'barbarous': 1, 'be': 8, 'be,': 1, 'bear': 1, 'become': 1, 'becomes': 2, 'been': 4, 'begun': 1, 'benefits': 1, 'between': 1, 'beyond': 1, 'bodies': 2, 'boundaries,': 1, 'brethren,': 1, 'brethren.': 1, 'bring': 1, 'british': 2, 'burnt': 1, 'but': 1, 'by': 13, 'called': 1, 'candid': 1, 'captive': 1, 'cases': 1, 'cases,': 1, 'cause': 1, 'causes': 1, 'causes;': 1, 'certain': 1, 'changed': 1, 'character': 1, 'charters,': 1, 'circumstances': 2, 'citizens': 1, 'civil': 1, 'civilized': 1, 'coasts,': 1, 'colonies': 1, 'colonies,': 1, 'colonies:': 1, 'colonies;': 1, 'combined': 1, 'commerce,': 1, 'commit': 1, 'common': 1, 'compleat': 1, 'compliance': 1, 'conclude': 1, 'conditions': 1, 'conditions.': 1, 'congress,': 1, 'conjured': 1, 'connected': 1, 'connection': 1, 'connections': 1, 'consanguinity.': 1, 'consent': 2, 'consent:': 1, 'constitution,': 1, 'constrained': 1, 'constrains': 1, 'contract': 1, 'convulsions': 1, 'correspondence.': 1, 'country,': 1, 'course': 1, 'created': 1, 'creator': 1, 'crown,': 1, 'cruelty': 1, 'cutting': 1, 'dangers': 1, 'deaf': 1, 'death,': 1, 'decent': 1, 'declaration,': 1, 'declare': 1, 'declare,': 1, 'declaring': 2, 'define': 1, 'denounces': 1, 'dependent': 1, 'depository': 1, 'depriving': 1, 'deriving': 1, 'design': 1, 'desolation,': 1, 'despotism,': 1, 'destroyed': 1, 'destruction,': 1, 'destructive': 1, 'dictate': 1, 'direct': 1, 'disavow': 1, 'disposed': 1, 'dissolutions,': 1, 'dissolve': 1, 'dissolved': 1, 'dissolved;': 1, 'distant': 1, 'districts': 1, 'divine': 1, 'do': 1, 'do,': 1, 'do.': 1, 'domestic': 1, 'duty,': 1, 'each': 1, 'earth,': 1, 'eat': 1, 'effect': 1, 'elected;': 1, 'emigration': 1, 'encourage': 1, 'endeavoured': 2, 'endowed': 1, 'ends,': 1, 'enemies': 1, 'english': 1, 'enlarging': 1, 'entitle': 1, 'equal': 1, 'equal,': 1, 'erected': 1, 'establish': 1, 'established': 1, 'establishing': 2, 'establishment': 1, 'events,': 1, 'every': 2, 'evils': 1, 'evinces': 1, 'example': 1, 'excited': 1, 'executioners': 1, 'exercise;': 1, 'experience': 1, 'exposed': 1, 'extend': 1, 'facts': 1, 'fall': 1, 'fatiguing': 1, 'fellow': 1, 'firm': 1, 'firmness': 1, 'fit': 1, 'for': 29, 'forbidden': 1, 'foreign': 2, 'foreigners;': 1, 'form': 1, 'form,': 1, 'former': 1, 'formidable': 1, 'forms': 2, 'fortunes,': 1, 'foundation': 1, 'free': 4, 'friends': 1, 'friends.': 1, 'from': 6, 'frontiers,': 1, 'full': 1, 'fundamentally': 1, 'future': 1, 'general': 1, 'giving': 1, 'god': 1, 'good': 1, 'good.': 1, 'governed,': 1, 'government': 2, 'government,': 3, 'government.': 1, 'governments': 2, 'governments:': 1, 'governors': 1, 'great-britain': 1, 'great-britain,': 1, 'guards': 1, 'hands.': 1, 'happiness.': 1, 'happinessâ€”-that': 1, 'harrass': 1, 'has': 20, 'hath': 1, 'have': 11, 'having': 1, 'he': 19, 'head': 1, 'here,': 1, 'here.': 1, 'high': 1, 'his': 9, 'history': 2, 'hither': 1, 'hither,': 1, 'hold': 3, 'honor.': 1, 'houses': 1, 'human': 1, 'humble': 1, 'immediate': 1, 'impel': 1, 'importance,': 1, 'imposing': 1, 'in': 19, 'incapable': 1, 'indeed,': 1, 'independent': 4, 'indian': 1, 'inestimable': 1, 'inevitably': 1, 'inhabitants': 2, 'injuries': 1, 'injury.': 1, 'institute': 1, 'instituted': 1, 'instrument': 1, 'insurrections': 1, 'intentions,': ...

# %%
# making it more legible

for key, value in enumerate(declaration.items(), 1):
    #print(key, value)
    print(f"""\x1B[1m{key}: {value}\x1B[0m""")
# Out:
# 1: ('a', 16)
# 2: ('abdicated', 1)
# 3: ('abolish', 1)
# 4: ('abolishing', 3)
# 5: ('absolute', 3)
# 6: ('absolved', 1)
# 7: ('abuses', 1)
# 8: ('accommodation', 1)
# 9: ('accordingly', 1)
# 10: ('accustomed.', 1)
# 11: ('acquiesce', 1)
# 12: ('act', 1)
# 13: ('acts', 2)
# 14: ('administration', 1)
# 15: ('affected', 1)
# 16: ('after', 1)
# 17: ('against', 2)
# 18: ('ages,', 2)
# 19: ('all', 10)
# 20: ('allegiance', 1)
# 21: ('alliances,', 1)
# 22: ('alone,', 1)
# 23: ('already', 1)
# 24: ('alter', 2)
# 25: ('altering', 1)
# 26: ('america,', 1)
# 27: ('among', 5)
# 28: ('amongst', 1)
# 29: ('amount', 1)
# 30: ('an', 5)
# 31: ('and', 57)
# 32: ('annihilation,', 1)
# 33: ('another,', 1)
# 34: ('answered', 1)
# 35: ('any', 2)
# 36: ('appealed', 1)
# 37: ('appealing', 1)
# 38: ('appropriations', 1)
# 39: ('arbitrary', 1)
# 40: ('are', 8)
# 41: ('are,', 1)
# 42: ('armed', 1)
# 43: ('armies', 1)
# 44: ('armies,', 1)
# 45: ('arms', 1)
# 46: ('as', 4)
# 47: ('assembled,', 1)
# 48: ('assent', 4)
# 49: ('assume', 1)
# 50: ('at', 4)
# 51: ('attempts', 1)
# 52: ('attend', 1)
# 53: ('attentions', 1)
# 54: ('authority', 1)
# 55: ('away', 1)
# 56: ('bands', 1)
# 57: ('barbarous', 1)
# 58: ('be', 8)
# 59: ('be,', 1)
# 60: ('bear', 1)
# 61: ('become', 1)
# 62: ('becomes', 2)
# 63: ('been', 4)
# 64: ('begun', 1)
# 65: ('benefits', 1)
# 66: ('between', 1)
# 67: ('beyond', 1)
# 68: ('bodies', 2)
# 69: ('boundaries,', 1)
# 70: ('brethren,', 1)
# 71: ('brethren.', 1)
# 72: ('bring', 1)
# 73: ('british', 2)
# 74: ('burnt', 1)
# 75: ('but', 1)
# 76: ('by', 13)
# 77: ('called', 1)
# 78: ('candid', 1)
# 79: ('captive', 1)
# 80: ('cases', 1)
# 81: ('cases,', 1)
# 82: ('cause', 1)
# 83: ('causes', 1)
# 84: ('causes;', 1)
# 85: ('certain', 1)
# 86: ('changed', 1)
# 87: ('character', 1)
# 88: ('charters,', 1)
# 89: ('circumstances', 2)
# 90: ('citizens', 1)
# 91: ('civil', 1)
# 92: ('civilized', 1)
# 93: ('coasts,', 1)
# 94: ('colonies', 1)
# 95: ('colonies,', 1)
# 96: ('colonies:', 1)
# 97: ('colonies;', 1)
# 98: ('combined', 1)
# 99: ('commerce,', 1)
# 100: ('commit', 1)
# 101: ('common', 1)
# 102: ('compleat', 1)
# 103: ('compliance', 1)
# 104: ('conclude', 1)
# 105: ('conditions', 1)
# 106: ('conditions.', 1)
# 107: ('congress,', 1)
# 108: ('conjured', 1)
# 109: ('connected', 1)
# 110: ('connection', 1)
# 111: ('connections', 1)
# 112: ('consanguinity.', 1)
# 113: ('consent', 2)
# 114: ('consent:', 1)
# 115: ('constitution,', 1)
# 116: ('constrained', 1)
# 117: ('constrains', 1)
# 118: ('contract', 1)
# 119: ('convulsions', 1)
# 120: ('correspondence.', 1)
# 121: ('country,', 1)
# 122: ('course', 1)
# 123: ('created', 1)
# 124: ('creator', 1)
# 125: ('crown,', 1)
# 126: ('cruelty', 1)
# 127: ('cutting', 1)
# 128: ('dangers', 1)
# 129: ('deaf', 1)
# 130: ('death,', 1)
# 131: ('decent', 1)
# 132: ('declaration,', 1)
# 133: ('declare', 1)
# 134: ('declare,', 1)
# 135: ('declaring', 2)
# 136: ('define', 1)
# 137: ('denounces', 1)
# 138: ('dependent', 1)
# 139: ('depository', 1)
# 140: ('depriving', 1)
# 141: ('deriving', 1)
# 142: ('design', 1)
# 143: ('desolation,', 1)
# 144: ('despotism,', 1)
# 145: ('destroyed', 1)
# 146: ('destruction,', 1)
# 147: ('destructive', 1)
# 148: ('dictate', 1)
# 149: ('direct', 1)
# 150: ('disavow', 1)
# 151: ('disposed', 1)
# 152: ('dissolutions,', 1)
# 153: ('dissolve', 1)
# 154: ('dissolved', 1)
# 155: ('dissolved;', 1)
# 156: ('distant', 1)
# 157: ('districts', 1)
# 158: ('divine', 1)
# 159: ('do', 1)
# 160: ('do,', 1)
# 161: ('do.', 1)
# 162: ('domestic', 1)
# 163: ('duty,', 1)
# 164: ('each', 1)
# 165: ('earth,', 1)
# 166: ('eat', 1)
# 167: ('effect', 1)
# 168: ('elected;', 1)
# 169: ('emigration', 1)
# 170: ('encourage', 1)
# 171: ('endeavoured', 2)
# 172: ('endowed', 1)
# 173: ('ends,', 1)
# 174: ('enemies', 1)
# 175: ('english', 1)
# 176: ('enlarging', 1)
# 177: ('entitle', 1)
# 178: ('equal', 1)
# 179: ('equal,', 1)
# 180: ('erected', 1)
# 181: ('establish', 1)
# 182: ('established', 1)
# 183: ('establishing', 2)
# 184: ('establishment', 1)
# 185: ('events,', 1)
# 186: ('every', 2)
# 187: ('evils', 1)
# 188: ('evinces', 1)
# 189: ('example', 1)
# 190: ('excited', 1)
# 191: ('executioners', 1)
# 192: ('exercise;', 1)
# 193: ('experience', 1)
# 194: ('exposed', 1)
# 195: ('extend', 1)
# 196: ('facts', 1)
# 197: ('fall', 1)
# 198: ('fatiguing', 1)
# 199: ('fellow', 1)
# 200: ('firm', 1)
# 201: ('firmness', 1)
# 202: ('fit', 1)
# 203: ('for', 29)
# 204: ('forbidden', 1)
# 205: ('foreign', 2)
# 206: ('foreigners;', 1)
# 207: ('form', 1)
# 208: ('form,', 1)
# 209: ('former', 1)
# 210: ('formidable', 1)
# 211: ('forms', 2)
# 212: ('fortunes,', 1)
# 213: ('foundation', 1)
# 214: ('free', 4)
# 215: ('friends', 1)
# 216: ('friends.', 1)
# 217: ('from', 6)
# 218: ('frontiers,', 1)
# 219: ('full', 1)
# 220: ('fundamentally', 1)
# 221: ('future', 1)
# 222: ('general', 1)
# 223: ('giving', 1)
# 224: ('god', 1)
# 225: ('good', 1)
# 226: ('good.', 1)
# 227: ('governed,', 1)
# 228: ('government', 2)
# 229: ('government,', 3)
# 230: ('government.', 1)
# 231: ('governments', 2)
# 232: ('governments:', 1)
# 233: ('governors', 1)
# 234: ('great-britain', 1)
# 235: ('great-britain,', 1)
# 236: ('guards', 1)
# 237: ('hands.', 1)
# 238: ('happiness.', 1)
# 239: ('happinessâ€”-that', 1)
# 240: ('harrass', 1)
# 241: ('has', 20)
# 242: ('hath', 1)
# 243: ('have', 11)
# 244: ('having', 1)
# 245: ('he', 19)
# 246: ('head', 1)
# 247: ('here,', 1)
# 248: ('here.', 1)
# 249: ('high', 1)
# 250: ('his', 9)
# 251: ('history', 2)
# 252: ('hither', 1)
# 253: ('hither,', 1)
# 254: ('hold', 3)
# 255: ('honor.', 1)
# 256: ('houses', 1)
# 257: ('human', 1)
# 258: ('humble', 1)
# 259: ('immediate', 1)
# 260: ('impel', 1)
# 261: ('importance,', 1)
# 262: ('imposing', 1)
# 263: ('in', 19)
# 264: ('incapable', 1)
# 265: ('indeed,', 1)
# 266: ('independent', 4)
# 267: ('indian', 1)
# 268: ('inestimable', 1)
# 269: ('inevitably', 1)
# 270: ('inhabitants', 2)
# 271: ('injuries', 1)
# 272: ('injury.', 1)
# 273: ('institute', 1)
# 274: ('instituted', 1)
# 275: ('instrument', 1)
# 276: ('insurrections', 1)
# 277: ('intentions,', 1)
# 278: ('interrupt', 1)
# 279: ('into', 2)
# 280: ('introducing', 1)
# 281: ('invariably', 1)
# 282: ('invasion', 1)
# 283: ('invasions', 1)
# 284: ('invested', 1)
# 285: ('is', 9)
# 286: ('is,', 1)
# 287: ('it', 5)
# 288: ('it,', 1)
# 289: ('its', 3)
# 290: ('judge', 1)
# 291: ('judges', 1)
# 292: ('judiciary', 1)
# 293: ('jurisdiction', 2)
# 294: ('jury:', 1)
# 295: ('just', 1)
# 296: ('justice', 2)
# 297: ('justice,', 1)
# 298: ('kept', 1)
# 299: ('kindred', 1)
# 300: ('king', 1)
# 301: ('known', 1)
# 302: ('lands.', 1)
# 303: ('large', 4)
# 304: ('laws', 6)
# 305: ('laws,', 2)
# 306: ('laws;', 1)
# 307: ('laying', 1)
# 308: ('legislate', 1)
# 309: ('legislation:', 1)
# 310: ('legislative', 2)
# 311: ('legislature', 1)
# 312: ('legislature,', 1)
# 313: ('legislatures,', 1)
# 314: ('legislatures.', 1)
# 315: ('let', 1)
# 316: ('levy', 1)
# 317: ('liberty,', 1)
# 318: ('life,', 1)
# 319: ('light', 1)
# 320: ('likely', 1)
# 321: ('lives', 1)
# 322: ('lives,', 1)
# 323: ('long', 3)
# 324: ('made', 1)
# 325: ('magnanimity,', 1)
# 326: ('mankind', 2)
# 327: ('mankind,', 1)
# 328: ('manly', 1)
# 329: ('many', 1)
# 330: ('marked', 1)
# 331: ('may', 2)
# 332: ('mean', 1)
# 333: ('measures.', 1)
# 334: ('men', 1)
# 335: ('men,', 1)
# 336: ('mercenaries', 1)
# 337: ('merciless', 1)
# 338: ('migrations', 1)
# 339: ('military', 1)
# 340: ('mock', 1)
# 341: ('more', 1)
# 342: ('most', 5)
# 343: ('multitude', 1)
# 344: ('murders', 1)
# 345: ('must,', 1)
# 346: ('mutually', 1)
# 347: ('name,', 1)
# 348: ('nation.', 1)
# 349: ('native', 1)
# 350: ('naturalization', 1)
# 351: ('nature', 1)
# 352: ('natureâ€™s', 1)
# 353: ('necessary', 2)
# 354: ('necessity', 1)
# 355: ('necessity,', 1)
# 356: ('neglected', 1)
# 357: ('neighbouring', 1)
# 358: ('new', 4)
# 359: ('nor', 1)
# 360: ('not', 1)
# 361: ('now', 1)
# 362: ('object', 1)
# 363: ('object,', 1)
# 364: ('obstructed', 1)
# 365: ('obstructing', 1)
# 366: ('obtained;', 1)
# 367: ('of', 76)
# 368: ('off', 2)
# 369: ('offences:', 1)
# 370: ('officers', 1)
# 371: ('offices,', 2)
# 372: ('on', 8)
# 373: ('once', 1)
# 374: ('one', 1)
# 375: ('only', 1)
# 376: ('only.', 1)
# 377: ('operation', 1)
# 378: ('opinions', 1)
# 379: ('opposing', 1)
# 380: ('oppressions', 1)
# 381: ('or', 2)
# 382: ('organizing', 1)
# 383: ('other', 3)
# 384: ('others', 3)
# 385: ('ought', 2)
# 386: ('our', 26)
# 387: ('out', 2)
# 388: ('over', 2)
# 389: ('own', 1)
# 390: ('paralleled', 1)
# 391: ('parts', 1)
# 392: ('pass', 3)
# 393: ('patient', 1)
# 394: ('payment', 1)
# 395: ('peace,', 3)
# 396: ('people', 5)
# 397: ('people,', 2)
# 398: ('people.', 3)
# 399: ('perfidy,', 1)
# 400: ('petitioned', 1)
# 401: ('petitions', 1)
# 402: ('places', 1)
# 403: ('pledge', 1)
# 404: ('plundered', 1)
# 405: ('political', 2)
# 406: ('population', 1)
# 407: ('power', 2)
# 408: ('power.', 1)
# 409: ('powers', 3)
# 410: ('powers,', 1)
# 411: ('powers.', 1)
# 412: ('present', 1)
# 413: ('pressing', 1)
# 414: ('pretended', 2)
# 415: ('prevent', 1)
# 416: ('prince,', 1)
# 417: ('principles,', 1)
# 418: ('protecting', 1)
# 419: ('protection', 2)
# 420: ('prove', 1)
# 421: ('provide', 1)
# 422: ('providence,', 1)
# 423: ('province,', 1)
# 424: ('prudence,', 1)
# 425: ('public', 2)
# 426: ('publish', 1)
# 427: ('punishment', 1)
# 428: ('purpose', 2)
# 429: ('pursuing', 1)
# 430: ('pursuit', 1)
# 431: ('quartering', 1)
# 432: ('raising', 1)
# 433: ('ravaged', 1)
# 434: ('records,', 1)
# 435: ('rectitude', 1)
# 436: ('redress', 1)
# 437: ('reduce', 1)
# 438: ('refused', 3)
# 439: ('refusing', 2)
# 440: ('reliance', 1)
# 441: ('relinquish', 1)
# 442: ('remaining', 1)
# 443: ('reminded', 1)
# 444: ('render', 2)
# 445: ('repeated', 3)
# 446: ('repeatedly,', 1)
# 447: ('representation', 1)
# 448: ('representative', 1)
# 449: ('representatives', 1)
# 450: ('requires', 1)
# 451: ('respect', 1)
# 452: ('rest', 1)
# 453: ('returned', 1)
# 454: ('right', 6)
# 455: ('right,', 1)
# 456: ('rights', 1)
# 457: ('rights,', 2)
# 458: ('rule', 2)
# 459: ('ruler', 1)
# 460: ('sacred', 1)
# 461: ('safety', 1)
# 462: ('salaries.', 1)
# 463: ('same', 2)
# 464: ('savages,', 1)
# 465: ('scarcely', 1)
# 466: ('seas', 2)
# 467: ('seas,', 1)
# 468: ('secure', 1)
# 469: ('security.', 1)
# 470: ('seem', 1)
# 471: ('self-evident,', 1)
# 472: ('sent', 1)
# 473: ('separate', 1)
# 474: ('separation,', 1)
# 475: ('separation.', 1)
# 476: ('settlement', 1)
# 477: ('sexes', 1)
# 478: ('shall', 1)
# 479: ('shewn,', 1)
# 480: ('should', 4)
# 481: ('so', 2)
# 482: ('sole', 1)
# 483: ('solemnly', 1)
# 484: ('stage', 1)
# 485: ('standing', 1)
# 486: ('state', 2)
# 487: ('states', 2)
# 488: ('states,', 1)
# 489: ('states.', 1)
# 490: ('states:', 1)
# 491: ('states;', 2)
# 492: ('station', 1)
# 493: ('subject', 1)
# 494: ('submitted', 1)
# 495: ('substance.', 1)
# 496: ('such', 6)
# 497: ('suffer,', 1)
# 498: ('sufferable,', 1)
# 499: ('sufferance', 1)
# 500: ('superior', 1)
# 501: ('support', 1)
# 502: ('supreme', 1)
# 503: ('suspended', 1)
# 504: ('suspended,', 1)
# 505: ('suspending', 1)
# 506: ('swarms', 1)
# 507: ('system', 1)
# 508: ('systems', 1)
# 509: ('taken', 1)
# 510: ('taking', 1)
# 511: ('taxes', 1)
# 512: ('tenure', 1)
# 513: ('terms:', 1)
# 514: ('than', 1)
# 515: ('that', 12)
# 516: ('the', 76)
# 517: ('their', 20)
# 518: ('them', 10)
# 519: ('them,', 4)
# 520: ('them.', 1)
# 521: ('themselves', 3)
# 522: ('therefore,', 2)
# 523: ('therein', 1)
# 524: ('these', 13)
# 525: ('they', 7)
# 526: ('things', 1)
# 527: ('this', 2)
# 528: ('this,', 1)
# 529: ('those', 1)
# 530: ('throw', 1)
# 531: ('thus', 1)
# 532: ('ties', 1)
# 533: ('till', 1)
# 534: ('time', 3)
# 535: ('time,', 2)
# 536: ('times', 1)
# 537: ('to', 65)
# 538: ('together', 1)
# 539: ('too', 1)
# 540: ('totally', 2)
# 541: ('towns,', 1)
# 542: ('trade', 1)
# 543: ('train', 1)
# 544: ('transient', 1)
# 545: ('transporting', 2)
# 546: ('trial', 1)
# 547: ('trial,', 1)
# 548: ('tried', 1)
# 549: ('troops', 1)
# 550: ('truths', 1)
# 551: ('tyranny', 1)
# 552: ('tyranny,', 1)
# 553: ('tyrant,', 1)
# 554: ('tyrants', 1)
# 555: ('unacknowledged', 1)
# 556: ('unalienable', 1)
# 557: ('uncomfortable,', 1)
# 558: ('under', 1)
# 559: ('undistinguished', 1)
# 560: ('unfit', 1)
# 561: ('united', 2)
# 562: ('unless', 2)
# 563: ('unusual,', 1)
# 564: ('unwarrantable', 1)
# 565: ('unworthy', 1)
# 566: ('us', 5)
# 567: ('us,', 3)
# 568: ('us.', 2)
# 569: ('us:', 1)
# 570: ('usurpations,', 3)
# 571: ('utterly', 1)
# 572: ('valuable', 1)
# 573: ('voice', 1)
# 574: ('waging', 1)
# 575: ('wanting', 1)
# 576: ('war', 1)
# 577: ('war,', 2)
# 578: ('warfare,', 1)
# 579: ('warned', 1)
# 580: ('we', 10)
# 581: ('we,', 1)
# 582: ('whatsoever.', 1)
# 583: ('when', 3)
# 584: ('whenever', 1)
# 585: ('whereby', 1)
# 586: ('which', 9)
# 587: ('which,', 1)
# 588: ('while', 1)
# 589: ('wholesome', 1)
# 590: ('whose', 2)
# 591: ('will', 2)
# 592: ('with', 9)
# 593: ('within.', 1)
# 594: ('without', 2)
# 595: ('without,', 1)
# 596: ('works', 1)
# 597: ('world', 1)
# 598: ('world.', 1)
# 599: ('world:', 1)
# 600: ('would', 2)

# %%
# sorting the dictionary by value

# creating a empty list
lst = list()

# creating a for loop
for key, value in list(declaration.items()):
    
    # appending values and keys to the list    
    lst.append((value, key))

# sorting the list in reverse order
lst.sort(reverse = True)

# creating a for loop
for key, value in lst:
    print(key, value)
# Out:
# 76 the
# 76 of
# 65 to
# 57 and
# 29 for
# 26 our
# 20 their
# 20 has
# 19 in
# 19 he
# 16 a
# 13 these
# 13 by
# 12 that
# 11 have
# 10 we
# 10 them
# 10 all
# 9 with
# 9 which
# 9 is
# 9 his
# 8 on
# 8 be
# 8 are
# 7 they
# 6 such
# 6 right
# 6 laws
# 6 from
# 5 us
# 5 people
# 5 most
# 5 it
# 5 an
# 5 among
# 4 them,
# 4 should
# 4 new
# 4 large
# 4 independent
# 4 free
# 4 been
# 4 at
# 4 assent
# 4 as
# 3 when
# 3 usurpations,
# 3 us,
# 3 time
# 3 themselves
# 3 repeated
# 3 refused
# 3 powers
# 3 people.
# 3 peace,
# 3 pass
# 3 others
# 3 other
# 3 long
# 3 its
# 3 hold
# 3 government,
# 3 absolute
# 3 abolishing
# 2 would
# 2 without
# 2 will
# 2 whose
# 2 war,
# 2 us.
# 2 unless
# 2 united
# 2 transporting
# 2 totally
# 2 time,
# 2 this
# 2 therefore,
# 2 states;
# 2 states
# 2 state
# 2 so
# 2 seas
# 2 same
# 2 rule
# 2 rights,
# 2 render
# 2 refusing
# 2 purpose
# 2 public
# 2 protection
# 2 pretended
# 2 power
# 2 political
# 2 people,
# 2 over
# 2 out
# 2 ought
# 2 or
# 2 offices,
# 2 off
# 2 necessary
# 2 may
# 2 mankind
# 2 legislative
# 2 laws,
# 2 justice
# 2 jurisdiction
# 2 into
# 2 inhabitants
# 2 history
# 2 governments
# 2 government
# 2 forms
# 2 foreign
# 2 every
# 2 establishing
# 2 endeavoured
# 2 declaring
# 2 consent
# 2 circumstances
# 2 british
# 2 bodies
# 2 becomes
# 2 any
# 2 alter
# 2 ages,
# 2 against
# 2 acts
# 1 world:
# 1 world.
# 1 world
# 1 works
# 1 without,
# 1 within.
# 1 wholesome
# 1 while
# 1 which,
# 1 whereby
# 1 whenever
# 1 whatsoever.
# 1 we,
# 1 warned
# 1 warfare,
# 1 war
# 1 wanting
# 1 waging
# 1 voice
# 1 valuable
# 1 utterly
# 1 us:
# 1 unworthy
# 1 unwarrantable
# 1 unusual,
# 1 unfit
# 1 undistinguished
# 1 under
# 1 uncomfortable,
# 1 unalienable
# 1 unacknowledged
# 1 tyrants
# 1 tyrant,
# 1 tyranny,
# 1 tyranny
# 1 truths
# 1 troops
# 1 tried
# 1 trial,
# 1 trial
# 1 transient
# 1 train
# 1 trade
# 1 towns,
# 1 too
# 1 together
# 1 times
# 1 till
# 1 ties
# 1 thus
# 1 throw
# 1 those
# 1 this,
# 1 things
# 1 therein
# 1 them.
# 1 than
# 1 terms:
# 1 tenure
# 1 taxes
# 1 taking
# 1 taken
# 1 systems
# 1 system
# 1 swarms
# 1 suspending
# 1 suspended,
# 1 suspended
# 1 supreme
# 1 support
# 1 superior
# 1 sufferance
# 1 sufferable,
# 1 suffer,
# 1 substance.
# 1 submitted
# 1 subject
# 1 station
# 1 states:
# 1 states.
# 1 states,
# 1 standing
# 1 stage
# 1 solemnly
# 1 sole
# 1 shewn,
# 1 shall
# 1 sexes
# 1 settlement
# 1 separation.
# 1 separation,
# 1 separate
# 1 sent
# 1 self-evident,
# 1 seem
# 1 security.
# 1 secure
# 1 seas,
# 1 scarcely
# 1 savages,
# 1 salaries.
# 1 safety
# 1 sacred
# 1 ruler
# 1 rights
# 1 right,
# 1 returned
# 1 rest
# 1 respect
# 1 requires
# 1 representatives
# 1 representative
# 1 representation
# 1 repeatedly,
# 1 reminded
# 1 remaining
# 1 relinquish
# 1 reliance
# 1 reduce
# 1 redress
# 1 rectitude
# 1 records,
# 1 ravaged
# 1 raising
# 1 quartering
# 1 pursuit
# 1 pursuing
# 1 punishment
# 1 publish
# 1 prudence,
# 1 province,
# 1 providence,
# 1 provide
# 1 prove
# 1 protecting
# 1 principles,
# 1 prince,
# 1 prevent
# 1 pressing
# 1 present
# 1 powers.
# 1 powers,
# 1 power.
# 1 population
# 1 plundered
# 1 pledge
# 1 places
# 1 petitions
# 1 petitioned
# 1 perfidy,
# 1 payment
# 1 patient
# 1 parts
# 1 paralleled
# 1 own
# 1 organizing
# 1 oppressions
# 1 opposing
# 1 opinions
# 1 operation
# 1 only.
# 1 only
# 1 one
# 1 once
# 1 officers
# 1 offences:
# 1 obtained;
# 1 obstructing
# 1 obstructed
# 1 object,
# 1 object
# 1 now
# 1 not
# 1 nor
# 1 neighbouring
# 1 neglected
# 1 necessity,
# 1 necessity
# 1 natureâ€™s
# 1 nature
# 1 naturalization
# 1 native
# 1 nation.
# 1 name,
# 1 mutually
# 1 must,
# 1 murders
# 1 multitude
# 1 more
# 1 mock
# 1 military
# 1 migrations
# 1 merciless
# 1 mercenaries
# 1 men,
# 1 men
# 1 measures.
# 1 mean
# 1 marked
# 1 many
# 1 manly
# 1 mankind,
# 1 magnanimity,
# 1 made
# 1 lives,
# 1 lives
# 1 likely
# 1 light
# 1 life,
# 1 liberty,
# 1 levy
# 1 let
# 1 legislatures.
# 1 legislatures,
# 1 legislature,
# 1 legislature
# 1 legislation:
# 1 legislate
# 1 laying
# 1 laws;
# 1 lands.
# 1 known
# 1 king
# 1 kindred
# 1 kept
# 1 justice,
# 1 just
# 1 jury:
# 1 judiciary
# 1 judges
# 1 judge
# 1 it,
# 1 is,
# 1 invested
# 1 invasions
# 1 invasion
# 1 invariably
# 1 introducing
# 1 interrupt
# 1 intentions,
# 1 insurrections
# 1 instrument
# 1 instituted
# 1 institute
# 1 injury.
# 1 injuries
# 1 inevitably
# 1 inestimable
# 1 indian
# 1 indeed,
# 1 incapable
# 1 imposing
# 1 importance,
# 1 impel
# 1 immediate
# 1 humble
# 1 human
# 1 houses
# 1 honor.
# 1 hither,
# 1 hither
# 1 high
# 1 here.
# 1 here,
# 1 head
# 1 having
# 1 hath
# 1 harrass
# 1 happinessâ€”-that
# 1 happiness.
# 1 hands.
# 1 guards
# 1 great-britain,
# 1 great-britain
# 1 governors
# 1 governments:
# 1 government.
# 1 governed,
# 1 good.
# 1 good
# 1 god
# 1 giving
# 1 general
# 1 future
# 1 fundamentally
# 1 full
# 1 frontiers,
# 1 friends.
# 1 friends
# 1 foundation
# 1 fortunes,
# 1 formidable
# 1 former
# 1 form,
# 1 form
# 1 foreigners;
# 1 forbidden
# 1 fit
# 1 firmness
# 1 firm
# 1 fellow
# 1 fatiguing
# 1 fall
# 1 facts
# 1 extend
# 1 exposed
# 1 experience
# 1 exercise;
# 1 executioners
# 1 excited
# 1 example
# 1 evinces
# 1 evils
# 1 events,
# 1 establishment
# 1 established
# 1 establish
# 1 erected
# 1 equal,
# 1 equal
# 1 entitle
# 1 enlarging
# 1 english
# 1 enemies
# 1 ends,
# 1 endowed
# 1 encourage
# 1 emigration
# 1 elected;
# 1 effect
# 1 eat
# 1 earth,
# 1 each
# 1 duty,
# 1 domestic
# 1 do.
# 1 do,
# 1 do
# 1 divine
# 1 districts
# 1 distant
# 1 dissolved;
# 1 dissolved
# 1 dissolve
# 1 dissolutions,
# 1 disposed
# 1 disavow
# 1 direct
# 1 dictate
# 1 destructive
# 1 destruction,
# 1 destroyed
# 1 despotism,
# 1 desolation,
# 1 design
# 1 deriving
# 1 depriving
# 1 depository
# 1 dependent
# 1 denounces
# 1 define
# 1 declare,
# 1 declare
# 1 declaration,
# 1 decent
# 1 death,
# 1 deaf
# 1 dangers
# 1 cutting
# 1 cruelty
# 1 crown,
# 1 creator
# 1 created
# 1 course
# 1 country,
# 1 correspondence.
# 1 convulsions
# 1 contract
# 1 constrains
# 1 constrained
# 1 constitution,
# 1 consent:
# 1 consanguinity.
# 1 connections
# 1 connection
# 1 connected
# 1 conjured
# 1 congress,
# 1 conditions.
# 1 conditions
# 1 conclude
# 1 compliance
# 1 compleat
# 1 common
# 1 commit
# 1 commerce,
# 1 combined
# 1 colonies;
# 1 colonies:
# 1 colonies,
# 1 colonies
# 1 coasts,
# 1 civilized
# 1 civil
# 1 citizens
# 1 charters,
# 1 character
# 1 changed
# 1 certain
# 1 causes;
# 1 causes
# 1 cause
# 1 cases,
# 1 cases
# 1 captive
# 1 candid
# 1 called
# 1 but
# 1 burnt
# 1 bring
# 1 brethren.
# 1 brethren,
# 1 boundaries,
# 1 beyond
# 1 between
# 1 benefits
# 1 begun
# 1 become
# 1 bear
# 1 be,
# 1 barbarous
# 1 bands
# 1 away
# 1 authority
# 1 attentions
# 1 attend
# 1 attempts
# 1 assume
# 1 assembled,
# 1 arms
# 1 armies,
# 1 armies
# 1 armed
# 1 are,
# 1 arbitrary
# 1 appropriations
# 1 appealing
# 1 appealed
# 1 answered
# 1 another,
# 1 annihilation,
# 1 amount
# 1 amongst
# 1 america,
# 1 altering
# 1 already
# 1 alone,
# 1 alliances,
# 1 allegiance
# 1 after
# 1 affected
# 1 administration
# 1 act
# 1 acquiesce
# 1 accustomed.
# 1 accordingly
# 1 accommodation
# 1 abuses
# 1 absolved
# 1 abolish
# 1 abdicated

# %%
# How many times is "united" mentioned in the declaration?

for key, value in declaration.items():
    if key == "united":
        print(key, value)
# Out:
# united 2

# %% [markdown]
# # CLASS ACTIVITY 2
#
# **Create a function that returns the value of a given key.**

# %%
# CLASS ACTIVITY 2 SOLUTION

#how to find the key given the value

# to find the KEY given the VALUE you have to create a custom function
def declarationFunc(keyword):
    for key, value in declaration.items():
        if keyword == key:
            #return value
            print(f"""The term \x1B[1m{keyword}\x1B[0m is mentioned \x1B[1m{value}\x1B[0m time(s) in the Declaration of Independence.""")

declarationFunc("united")
# Out:
# The term united is mentioned 2 time(s) in the Declaration of Independence.

# %%
# Remember this?
# This is the code we started with in the beginning of the semester
# For each line, someone (taking turns) explain to me what's going on?

name = input('Enter file:')
handle = open(name)

counts = dict()
for line in handle:
    words = line.split()
    for word in words:
        counts[word] = counts.get(word,0) + 1

bigcount = None
bigword = None
for word,count in counts.items():
    if bigcount is None or count > bigcount:
        bigword = word
        bigcount = count

print(bigword, bigcount)
