# %%
#input #1

#creating a list of major cities in the Bay Area
major_cities = ["San Jose", "San Francisco", "Oakland", "Fremont", "Santa Rosa",
               "Hayward", "Sunnyvale", "Santa Clara", "Vallejo", "Concord", "Berkeley",
               "Fairfield", "Richmond", "Antioch", "San Mateo", "Daly City", "San Leandro"]

city = input(prompt = """
Name a major city in the Bay Area: """)

while city.title() not in major_cities:
    if city.title() not in major_cities:
        city = input(prompt = """
        That is not considered a major city in the Bay Area.
        Pick another city:  """)
    else:
        pass
    
#input #2
# creating a list of popular fast foods
popular_fastfoods = ["mcdonalds", "jack in the box", "subway", "chipotle", "taco bell", "wendys", 
                     "panda express", "burger king", "in n out", "raising canes", "starbucks", "chick fil a"]
fastfood = input(prompt = """
Name a popular fast food resturant in the United States: """)

#while loop to make sure the fast food is referenced is in the fast food list
while fastfood.casefold() not in popular_fastfoods:
    if fastfood.casefold() not in popular_fastfoods:
        fastfood = input(prompt = """
        That is not considered a popular fast food in the US.
        Pick another fast food: """)
    else:
        pass   
    
#input #3

#creating a list of weekdays
week_day = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday",
           "Sun", "Mon", "Tues", "Wed", "Thurs", "Fri", "Sat"]

day = input(prompt = """
Name a day in the week: """) 
    
#while loop to make sure the day is from a day in the week
while day.capitalize() not in week_day:
    if day.capitalize() not in week_day:
        day = input(prompt = """
        That entry is not recognized. Check your spelling.
        Pick a day in the week: """)
    else:
        pass

#input #4
city2 = input(prompt = """
Name another major city in the Bay Area: """) 

#while loop to make sure the city is referenced properly
while city2.title() == city.title() or city2.title() not in major_cities:
    if city2.title() == city.title() or city2.title() not in major_cities:
        city2 = input(prompt = """
        Pick a DIFFERENT major city in the Bay Area: """)
    else:
        pass
    
#input #5 

#create a list of months in the year
year_months = ["Jan", "January", "Feb", "February", "Mar", "March", "Apr", 
                 "April", "May", "Jun", "June", "Jul", "July", "Aug", "August",
                 "Sept", "Sep", "September", "Oct", "October", "Nov", "November",
                 "Dec", "December"]

month = input(prompt = """
Name a month in the year: """) 

#while loop to make sure the month is properly referenced
while month.capitalize not in year_months:
    if month.capitalize() not in year_months:
        month = input(prompt = """
        You possibly misspelled the month. Try again. 
        Name a month in the year: """)
    else:
        break


#input #6 

year = int(input(prompt = """
Pick a year between 2023 and 2033: """))

#while loop to make sure year was between 2023 and 2033
while year <= 2023 or year >= 2033:
    if year >= 2023 and year <= 2033:
        break
    else:
        year = int(input(prompt = """ 
        Your input of '{}' is not valid.
        Pick a year between 2023 and 2033: """.format(year)))

#input #7

number1 = int(input(prompt = "Pick a number between 1 and 10: "))

#while loop to make sure number was between 1 and 10
while number1 <= 1 or number1 >= 10:
    if number1 >= 1 and number1 <= 10:
        break
    else:
        number1 = int(input(prompt = """
        Your input of '{}' is not valid.
        Pick a number between 1 and 10: """.format(number1)))

#input #8 
number2 = int(input(prompt = """
Pick another number between 1 and 10. """))

while number2 == number1 or number2 <= 1 or number2 >= 10:
    if number2 == number1 or number2 <= 1 or number2 >= 10:
        number2 = int(input(prompt = """
        Please pick a DIFFERENT number between 1 and 10.
        Pick another number between 1 and 10. """))             
    else:
        break
        
#input #9 
number3 = int(input("Pick a number between 10 and 20: "))

#while loop to make sure numbers are between 10 and 20
while number3 < 10 or number3 > 20:
    number3 = int(input("""
    Your input of '{}' is not valid.
    Pick a number between 10 and 20: """.format(number3)))
else:
    pass
    
        
#print statement
print(f"""
{'*' * 80}

The \x1B[1m{city.capitalize()}\x1B[0m City Council wants to bring a 
new fast food \x1B[1m{fastfood.capitalize()}\x1B[0m Association resturant to \x1B[1m{city.capitalize()}\x1B[0m.

On \x1B[1m{day.capitalize()}\x1B[0m, the council approved a resolution urging the association 
to establish a resturant in \x1B[1m{city.capitalize()}\x1B[0m, noting the city is has 
abadoned square footage and wants to grow it's city economy. 

A handful of other cities including \x1B[1m{city2.title()}\x1B[0m are also attempting to open a new fast food resturant.
Govner Newson, confirmed in 
\x1B[1m{month.capitalize()}\x1B[0m that the state is looking to add \x1B[1m{number1}\x1B[0m or \x1B[1m{number2}\x1B[0m fast
food resturants in \x1B[1m{year}\x1B[0m. 

The Bay Area has \x1B[1m{number3}\x1B[0m resturants and is mainly looking to increase economic growth. 

{'*' * 80}

""")
# Out:
# Name a major city in the Bay Area: oakland
#
# Name a popular fast food resturant in the United States: subway
#
# Name a day in the week: monday
#
# Name another major city in the Bay Area: san leandro
#
# Name a month in the year: july
#
# Pick a year between 2023 and 2033: 2024
# Pick a number between 1 and 10: 2
#
# Pick another number between 1 and 10. 3
# Pick a number between 10 and 20: 11
#
# ********************************************************************************
#
# The Oakland City Council wants to bring a
# new fast food Subway Association resturant to Oakland.
#
# On Monday, the council approved a resolution urging the association
# to establish a resturant in Oakland, noting the city is has
# abadoned square footage and wants to grow it's city economy.
#
# A handful of other cities including San Leandro are also attempting to open a new fast food resturant.
# Govner Newson, confirmed in
# July that the state is looking to add 2 or 3 fast
# food resturants in 2024.
#
# The Bay Area has 11 resturants and is mainly looking to increase economic growth.
#
# ********************************************************************************
